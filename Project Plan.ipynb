# %% [markdown]
# ## **Final Capstone Project Plan**
# * Anime is hand-drawn and computer animation originating from or associated with Japan. Pokemon, Dragonball, etc. are examples of Anime.
# *   The goal of this project is to create a Anime recommendation algorithm and to recommend Anime according to the user's taste
# *   Once it is tuned to be as accurate as possible, it can provide value by recommending users which amime to watch and provide insights to companies what features are popular for anime.
# * I’ll implement an unsupervised machine learning model such as kmeans or others that can provide segementation on Anime viewers and providing the  number of clusters. Then try variety of supervised classification models to recommend an Anime to an user. This will be done through pyspark for big data.
# * The biggest challenge will be tuning for accuracy. The acceptable accuracy for businesses for models are usually around 80%.

# %% [markdown]
# ### **Technical Steps**
# * Load relevant data into pyspark.
# * Explore and clean up the data
# * Feature selection
# * Find the number of clusters through unsupervise models
# * Tune many variations in order to select the most accurate
# * Implement other classification models for comparison
# * Use the model to see recommendation of anime based on random animes.

# %% [markdown]
# ### **Data**
#
# I'll be using a dataset provided from https://www.kaggle.com/azathoth42/myanimelist#users_cleaned.csv.
#
# I'll be using the filtered csv because consists alot of user's information such as birth date, location and gender.
#
# * 116 133 unique users with demographic data
# * 35 802 010 records in anime lists
# * 20 726 794 of them have ratings
# * 14 474 unique anime
